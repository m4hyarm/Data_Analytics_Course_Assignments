# %% [markdown]
# <div style="display:block" direction=rtl align=right><br><br>
#     <div  style="width:100%;margin:100;display:block"  display=block align=center>
#         <img width=130 align=right src="https://i.ibb.co/yXKQmtZ/logo1.png" style="margin:0;" />
#         <img width=170 align=left  src="https://i.ibb.co/wLjqFkw/logo2.png" style="margin:0;" />
#         <span><br><font size=5>University of Tehran , school of ECE</font></span>
#         <span><br><font size=3>Data Analytics Course</font></span>
#         <span><br><font size=3>Fall 1400</font></span>
#     </div><br><br><br>
#     <div style="display:block" align=left display=block>
#         <font size=3>Hands-on 1</font><br>
#         <hr />
#         <font size=3>Is there any ؟ Question ? , Feel free to ask me  <a href="mailto:mohammad.nili@ut.ac.ir">mohammad nili</a> :)))<br></font><br>
#     </div>
# </div>

# %% [markdown]
# <pre>
# Read / manipulation Data & statistics
# $ ( click to jump on task )
# .
# ├── Import Data
# │   ├── Read Txt
# │   ├── context manager
# │   │    ├ <a href="#t1">task 1 - read first 5 line of txt file.</a>
# │   │    └ <a href="#t2">task 2 - split word of each line.</a>
# │   └── Flat files
# │       ├ numpy
# |       |
# │       ├ pandas
# │       | ├ <a href="#t3">task 3 - show one row</a>
# │       | ├ split column
# │       | | └ <a href="#t4">task 4 - split data column</a>
# │       | ├ filter
# │       | | └ <a href="#t5">task 5 - filter by condition</a>
# │       | └ group
# |       |
# │       └ log
# │         └ <a href="#t6">task 6 - load log data </a>
# |
# ├── Data cleaning
# │   ├── Data Type  Constraints
# │   ├── Data Range Constraints
# │   |   └ <a href="#t7">task 7 - Data Range minimum condition</a>
# │   ├── Uniqueness Constraints
# │   |   └ <a href="#t8">task 8 - Remove duplicate and missing values</a>
# │   ├── Categorical Variables
# │   |   └ <a href="#t9">task 9 - split vaccines column</a>
# │   ├── Membership Constraints
# │   |   └ <a href="#t10">task 10 - set of all vaccines</a>
# │   ├── Cleaning Text Data
# │   |   └ <a href="#t11">task 11 - clean web address text data</a>
# │   ├── Uniformity
# │   |   └ <a href="#t12">task 12 - rescale & reformat</a>
# │   ├── Completness
# │       | <a href="#t13">task 13 - interpolate missing values</a>
# │       └ <a href="#t14">task 14 - explain interpolation problem </a>
# |
# ├── Data statistics
# │   └── <a href="#t15">task 15 - statistics</a>
# |
# ├── Data manipulation
# │   └── <a href="#t16">task 16 - join tables</a>
# |
# └── Data visualization
#     └── <a href="#t17">task 17 - plot data</a>
#
# </pre>

# %% [markdown]
# <hr>

# %% [markdown]
# <font color=green>Use :</font> ``` ! conda install pandas numpy matplotlib ```
#
# <font color=red>Don't use :</font> ``` ! pip install pandas numpy matplotlib ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data
# - Flat files, <font color=green>(e.g :txt,csv)</font>
# - Files from other software <font color=green>(e.g :Matlab)</font>
# - Relational databases <font color=green>(e.g :PostgreSQL,MySQL,SQLite)</font>
#
# [Pandas I/O tools](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)<br>
# [numpy I/O tools](https://numpy.org/doc/stable/reference/routines.io.html)

# %% [markdown]
# ## Read Txt file :

# %%
filename = 'The_Great_Gatsby.txt'
file = open(filename , mode='r') # 'r' is for read
text = file.read()
file.close()
print(text)
# Out:
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever.
#
# Title: The Great Gatsby
#
# Author: F. Scott Fitzgerald
#
# Release Date: January 17, 2021 [eBook #64317]
# [Most recently updated: January 24 2021]
#
# Language: English
#
# Character set encoding: UTF-8
#
# Produced by: Alex Cabal for the Standard Ebooks project, based on a
#              transcription produced for Project Gutenberg Australia.

# %% [markdown]
# ## Read Text file [ use Context manager ]
# - To avoid having close the connection to the file use Context manager

# %% [markdown]
# <hr />
# <font color=orange size=5>Golden Hints</font>
#
# - use ```dir(your_object)``` to see list of built in methods of your object.
#
# ><font color=green>e.g : </font>
# `with open(filename , mode='r') as file:` <br>
# &emsp;&emsp;&emsp;&emsp;`print(dir(file))`
#
# - use `help(method)` or `help(instance)` to see __doc__ (doc string)
#
# ><font color=green>e.g :</font> `help(dir)`
#
# <hr />

# %% [markdown]
# <hr />
# <font color=red size=5 id="t1"> Task 1 :</font>
#
# Fill below code by using ```print(file.readline())``` or ```print(file.read())``` or ```print(file.readlines())``` to read first 5 line

# %%
with open(filename , mode='r') as file:
    text = file.readlines()
    for i in text[0:5]:
        print(i)
# Out:
# This eBook is for the use of anyone anywhere in the United States and
#
# most other parts of the world at no cost and with almost no restrictions
#
# whatsoever.
#
#
#
# Title: The Great Gatsby

# %% [markdown]
# <hr />
# <font color=red size=5 id="t2"> Task 2 :</font>
#
# Fill below code by using ```.split()``` built in method to split each line to words

# %%
with open(filename , mode='r') as file:
    lines = file.readlines()
    print(f"text file contain {len(lines)} lines \n\n")
    
    for line in lines:
        print(line.split())
# Out:
# text file contain 17 lines
#
#
# ['This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and']
# ['most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions']
# ['whatsoever.']
# []
# ['Title:', 'The', 'Great', 'Gatsby']
# []
# ['Author:', 'F.', 'Scott', 'Fitzgerald']
# []
# ['Release', 'Date:', 'January', '17,', '2021', '[eBook', '#64317]']
# ['[Most', 'recently', 'updated:', 'January', '24', '2021]']
# []
# ['Language:', 'English']
# []
# ['Character', 'set', 'encoding:', 'UTF-8']
# []
# ['Produced', 'by:', 'Alex', 'Cabal', 'for', 'the', 'Standard', 'Ebooks', 'project,', 'based', 'on', 'a']
# ['transcription', 'produced', 'for', 'Project', 'Gutenberg', 'Australia.']

# %% [markdown]
# <hr />

# %% [markdown]
# ## Non Flat files example  :
# > - spreadsheet consisting of many sheets, not a single table. (<font color=green>e.g : xlsx </font>)
# > - Relational databases (<font color=green>e.g : PostgreSQL </font>)
#
# ## Flat files
# > is a basic text file containing records, that is table data , without structured relationships. <br>
# > consists of a single table of data

# %% [markdown]
# #### import flat files by numpy

# %% [markdown]
# ``` np.loadtxt(filename,delimiter='\t',skiprows=1) ```
#
# ``` np.recfromcsv(filename,delimiter=',') ```
#
# ``` np.genfromtxt(filename,delimiter=',',names=True,dtype=None) ```

# %% [markdown]
# #### import flat files by pandas

# %%
filename = 'country_vaccinations.csv'
data = pd.read_csv(filename)

# %%
ir = data[data['country']=='Iran']
ir
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 19243    Iran      IRN  2021-02-08                 0.0                0.0
# 19244    Iran      IRN  2021-02-09              3000.0             3000.0
# 19245    Iran      IRN  2021-02-10                 NaN                NaN
# 19246    Iran      IRN  2021-02-11                 NaN                NaN
# 19247    Iran      IRN  2021-02-12                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 19463    Iran      IRN  2021-09-16                 NaN                NaN
# 19464    Iran      IRN  2021-09-17                 NaN                NaN
# 19465    Iran      IRN  2021-09-18          42003863.0         28382995.0
# 19466    Iran      IRN  2021-09-19                 NaN                NaN
# 19467    Iran      IRN  2021-09-20          43372270.0         29526662.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 19243                      NaN                     NaN                 NaN
# 19244                      NaN                  3000.0              3000.0
# 19245                      NaN                     NaN              1938.0
# 19246                      NaN                     NaN              1583.0
# 19247                      NaN                     NaN              1406.0
# ...                        ...                     ...                 ...
# 19463                      NaN                     NaN           1054676.0
# 19464                      NaN                     NaN           1084396.0
# 19465               13620868.0                     NaN           1114115.0
# 19466                      NaN                     NaN           1091560.0
# 19467               13961491.0                     NaN            945577.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 19243                            0.00                           0.00
# 19244                            0.00                           0.00
# 19245                             NaN                            NaN
# 19246                             NaN                            NaN
# 19247                             NaN                            NaN
# ...                               ...                            ...
# 19463                             NaN                            NaN
# 19464                             NaN                            NaN
# 19465                           49.40                          33.38
# 19466                             NaN                            NaN
# 19467                           51.01                          34.73
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 19243                                  NaN                             NaN
# 19244                                  NaN                            35.0
# 19245                                  NaN                            23.0
# 19246                                  NaN                            19.0
# 19247                                  NaN                            17.0
# ...                                    ...                             ...
# 19463                                  NaN                         12404.0
# 19464                                  NaN                         12753.0
# 19465                                16.02                         13103.0
# 19466                                  NaN                         12838.0
# 19467                                16.42                         11121.0
#
#                                                 vaccines  \
# 19243  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19244  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19245  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19246  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19247  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# ...                                                  ...
# 19463  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19464  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19465  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19466  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19467  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
#
#                      source_name            source_website
# 19243  World Health Organization  https://covid19.who.int/
# 19244  World Health Organization  https://covid19.who.int/
# 19245  World Health Organization  https://covid19.who.int/
# 19246  World Health Organization  https://covid19.who.int/
# 19247  World Health Organization  https://covid19.who.int/
# ...                          ...                       ...
# 19463  World Health Organization  https://covid19.who.int/
# 19464  World Health Organization  https://covid19.who.int/
# 19465  World Health Organization  https://covid19.who.int/
# 19466  World Health Organization  https://covid19.who.int/
# 19467  World Health Organization  https://covid19.who.int/
#
# [225 rows x 15 columns]

# %% [markdown]
# <hr />
# <font color=red size=5 id="t3"> Task 3 :</font>
#
# - show first  one row
# - show last   one row
# - show random one row

# %%
ir.head(1)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 19243    Iran      IRN  2021-02-08                 0.0                0.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 19243                      NaN                     NaN                 NaN
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 19243                             0.0                            0.0
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 19243                                  NaN                             NaN
#
#                                                 vaccines  \
# 19243  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
#
#                      source_name            source_website
# 19243  World Health Organization  https://covid19.who.int/

# %%
ir.tail(1)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 19467    Iran      IRN  2021-09-20          43372270.0         29526662.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 19467               13961491.0                     NaN            945577.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 19467                           51.01                          34.73
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 19467                                16.42                         11121.0
#
#                                                 vaccines  \
# 19467  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
#
#                      source_name            source_website
# 19467  World Health Organization  https://covid19.who.int/

# %%
ir.sample(1)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 19343    Iran      IRN  2021-05-19                 NaN                NaN
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 19343                      NaN                     NaN             90478.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 19343                             NaN                            NaN
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 19343                                  NaN                          1064.0
#
#                                                 vaccines  \
# 19343  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
#
#                      source_name            source_website
# 19343  World Health Organization  https://covid19.who.int/

# %% [markdown]
# ### split date column :

# %% [markdown]
# <hr />
# <font color=red size=5 id="t4"> Task 4 :</font>
#
# Use one of below code to split month from date column
#
# `data['date'].dt.strftime('%m')`
#
# `data['date'].str.split('-',expand=True)[1]`

# %%
data['month'] = data['date'].str.split('-',expand=True)[1]
data.head(1)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name  \
# 0  World Health Organization
#
#                                       source_website month
# 0  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...    02

# %% [markdown]
# ### filter data :
#
# > by using `dir(data)` we can find some useful methods :
# > - loc
# > - iloc
# > - where
# > - filter
# > - query
# > - take
# > - tail
# > - head
# > - sample
# > - pop
# > - nlargest
# > - get
#
#
# <font color=green>e.g :</font>
#
# ``` data.sample(4).iloc[:,6:10] ```
#
# ``` data.filter(items=['country', 'date']).head(10).tail(3) ```
#
# ``` data.loc[1200:1500,['country','month']] ```
#
# ``` data.where(data['country']=='Anguilla') ```
#
# ``` data[(data['country']=='Anguilla') & (data['month']=='07')] ```

# %% [markdown]
# <hr />
# <font color=red size=5 id="t5"> Task 5 :</font>
#
# Filter data by below conditions :
# - source_name  : World Health Organization
# - country      : Iran or Iraq
# - month        > 05

# %%
data[ (data['source_name']=='World Health Organization') & ((data['country']=='Iran') | (data['country']=='Iraq')) & (data['month']>'05') ]
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 19356    Iran      IRN  2021-06-01                 NaN                NaN
# 19357    Iran      IRN  2021-06-02                 NaN                NaN
# 19358    Iran      IRN  2021-06-03                 NaN                NaN
# 19359    Iran      IRN  2021-06-04                 NaN                NaN
# 19360    Iran      IRN  2021-06-05                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 19658    Iraq      IRQ  2021-09-07                 NaN                NaN
# 19659    Iraq      IRQ  2021-09-08           5739867.0          3684546.0
# 19660    Iraq      IRQ  2021-09-09                 NaN                NaN
# 19661    Iraq      IRQ  2021-09-10                 NaN                NaN
# 19662    Iraq      IRQ  2021-09-11           6672182.0          4203578.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 19356                      NaN                     NaN             94138.0
# 19357                      NaN                     NaN             94138.0
# 19358                      NaN                     NaN             94138.0
# 19359                      NaN                     NaN             94138.0
# 19360                      NaN                     NaN             94138.0
# ...                        ...                     ...                 ...
# 19658                      NaN                     NaN            187192.0
# 19659                2055321.0                     NaN            319337.0
# 19660                      NaN                     NaN            356600.0
# 19661                      NaN                     NaN            393862.0
# 19662                2468604.0                     NaN            431125.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 19356                             NaN                            NaN
# 19357                             NaN                            NaN
# 19358                             NaN                            NaN
# 19359                             NaN                            NaN
# 19360                             NaN                            NaN
# ...                               ...                            ...
# 19658                             NaN                            NaN
# 19659                           13.94                           8.95
# 19660                             NaN                            NaN
# 19661                             NaN                            NaN
# 19662                           16.20                          10.21
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 19356                                  NaN                          1107.0
# 19357                                  NaN                          1107.0
# 19358                                  NaN                          1107.0
# 19359                                  NaN                          1107.0
# 19360                                  NaN                          1107.0
# ...                                    ...                             ...
# 19658                                  NaN                          4546.0
# 19659                                 4.99                          7755.0
# 19660                                  NaN                          8660.0
# 19661                                  NaN                          9565.0
# 19662                                 5.99                         10469.0
#
#                                                 vaccines  \
# 19356  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19357  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19358  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19359  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 19360  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# ...                                                  ...
# 19658  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 19659  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 19660  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 19661  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 19662  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
#
#                      source_name            source_website month
# 19356  World Health Organization  https://covid19.who.int/    06
# 19357  World Health Organization  https://covid19.who.int/    06
# 19358  World Health Organization  https://covid19.who.int/    06
# 19359  World Health Organization  https://covid19.who.int/    06
# 19360  World Health Organization  https://covid19.who.int/    06
# ...                          ...                       ...   ...
# 19658  World Health Organization  https://covid19.who.int/    09
# 19659  World Health Organization  https://covid19.who.int/    09
# 19660  World Health Organization  https://covid19.who.int/    09
# 19661  World Health Organization  https://covid19.who.int/    09
# 19662  World Health Organization  https://covid19.who.int/    09
#
# [215 rows x 16 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# #### Grouping data :
# > by using `dir(data)` we can find some useful methods :
# > - groupby
#
# > - .agg()
# > - .aggregate()
# > - .min()
# > - .max()
# > - .sum()
# > - .count()
# > - .value_counts() params: `normalize=True`
# >> counts the unique values in a series (best choice for chategorical data)

# %%
data.groupby('country').max().head(2)
# Out:
#             iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan      AFG  2021-09-16           3133227.0           773002.0
# Albania          ALB  2021-09-19           1649884.0           918307.0
#
#              people_fully_vaccinated  daily_vaccinations_raw  \
# country
# Afghanistan                 430744.0                  4015.0
# Albania                     731577.0                 23655.0
#
#              daily_vaccinations  total_vaccinations_per_hundred  \
# country
# Afghanistan             72098.0                            7.87
# Albania                 17565.0                           57.43
#
#              people_vaccinated_per_hundred  \
# country
# Afghanistan                           1.94
# Albania                              31.96
#
#              people_fully_vaccinated_per_hundred  \
# country
# Afghanistan                                 1.08
# Albania                                    25.46
#
#              daily_vaccinations_per_million  \
# country
# Afghanistan                          1810.0
# Albania                              6114.0
#
#                                                       vaccines  \
# country
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Albania      Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
#
#                            source_name  \
# country
# Afghanistan  World Health Organization
# Albania             Ministry of Health
#
#                                                 source_website month
# country
# Afghanistan  https://app.powerbi.com/view?r=eyJrIjoiYTkyM2V...    09
# Albania      https://shendetesia.gov.al/vaksinimi-anticovid...    09

# %% [markdown]
# <hr>

# %% [markdown]
# ## working with Log files :

# %% [markdown]
# ### Take a look at first line :

# %%
filename = 'web.log'
with open(filename , mode='r') as file:
    print(file.readline())
# Out:
# 199.72.81.55 - - [01/Jul/1995:00:00:01 -0400] "GET /history/apollo/ HTTP/1.0" 200 6245

# %% [markdown]
# <hr >
#
# <font size=3 color=purple> Is there any specific seperator between columns ? </font>
#
# <font size=3 color=purple> Can we use `pd.read_csv` with '&nbsp;&nbsp;' seperator ? </font>
#
# <font size=3 color=purple> Lets try  : </font>

# %%
web_log = pd.read_csv( 
    'web.log', 
    sep=' ', 
    encoding='latin-1', 
    header=None, 
    names=['host', 'timestamp','method','status','content'] 
)

web_log.head(1)
# Out:
#                                    host timestamp  \
# 199.72.81.55 - -  [01/Jul/1995:00:00:01    -0400]
#
#                                          method  status  content
# 199.72.81.55 - -  GET /history/apollo/ HTTP/1.0     200     6245

# %% [markdown]
# <hr />
#
# <font color=red size=5 id="t6"> Task 6 :</font>
#
#
# ### Is there any  problem ? if yes describe the reason .
# <!-- > there are several seperators , but there is some pattern -->
# <!-- > so we use <font color=red>Regex</font> -->

# %% [markdown]
# <div dir="rtl" lang="fa" style="color:purple;font">بله،  اولا ستون host اشتباه نشان داده شده است  دوما ستون timestamp به اشتباه نصف شده است  سوما دو ستون اضافه با داده های بیهوده '-' ایجاد شده است</div>

# %% [markdown]
# <hr>

# %%
import re
 
log_file_path = r"web.log"
host_pattern  = r'(^\S+\.[\S+\.]+\S+)\s'

with open(log_file_path, "r") as file:
    for line in file:
        print([match for match in re.finditer(host_pattern, line, re.S)][0][0])
# Out:
# 199.72.81.55
# unicomp6.unicomp.net
# 199.120.110.21
# burger.letters.com
# 199.120.110.21

# %% [markdown]
# # Data cleaning :
# > by using `dir(data)` we can find some useful methods :
# > - .all()
# > - .any()
# > - .drop()
# > - .drop_duplicates()
# > - .dropna()
# > - .fillna()
# > - .isna()
# > - .isnull()
# > - .notna()
# > - .notnull()

# %% [markdown]
# ### Data Type  Constraints
#
# <font color=green>e.g :</font>
#
# ``` data.dtypes ```
#
# ``` assert data['country'].dtype == 'object' ```
#
# ``` assert data['total_vaccinations'].dtype == 'int64' ```

# %% [markdown]
# ### Data Range  Constraints
#
# <font color=green>e.g :</font>
#
# ``` assert data['date'].max() < datetime.date.today() ```

# %% [markdown]
# <hr />
# <font color=red size=5 id="t7"> Task 7 :</font>
#
# Check Data Range minimum condition for `total_vaccinations` column
#
# <!-- assert data['total_vaccinations'].min() >=0 -->

# %%
assert data['total_vaccinations'].min() >= 0

# %% [markdown]
# ### Uniqueness Constraints
#
# <font color=green>e.g :</font>
#
# ``` data[data.duplicated('country')].head(2) ```
#
# ``` data.drop_duplicates(inplace=True) ```
#
# ``` columns_list = ['country','daily_vaccinations_per_million','source_name']
# duplicated   = data[data.duplicated(subset=columns_list ,keep=False)].head(2) ```

# %% [markdown]
# <hr />
# <font color=red size=5 id="t8"> Task 8 :</font>
#
# Fill below code by peeking upper method list to clean `data` and strore that in new variable called `clean_data`
# - remove duplicated data
# - remove missing values

# %%
clean_data = data.drop_duplicates().dropna()

# %% [markdown]
# which columns of `data` has missing value ?
# > Hint :
# > use `isna()` method to find each cell is missed ? and after use `.any(axis= )` to reduce dimention and at the end use `.sum()` to count True values (True:1 , False:0) .
# > - axis=1 is for rows
# > - axis=0 is for columns

# %%
data.isna().any(axis=0).sum()
# Out:
# 9

# %% [markdown]
# <hr />

# %% [markdown]
# <hr>
#
# ### Categorical Variables
#
# <font color=green>e.g :</font>
#
# ``` data['country'].value_counts() params: normalize=True ```
#
# ``` data.groupby('country').count() ```
#
#
# `death_rate = ['good', 'bad', 'worse']
# data['death_rate'] = data.total_vaccinations.astype('category', ordered=True, categories=death_rate)`
#
# ``` data['country'] = data['country'].str.strip()  #for remove white space before & after of string column```
#
# ``` data['country'] = data['country'].str.lower()  #make lowercase the string column```

# %% [markdown]
# <hr />
# <font color=red size=5 id="t9"> Task 9 :</font>
#
# Fill below code with ideas of upper examples:
#
# - split vaccines colummn of `data` as `splitted_vaccines`
#
# - make `first_vac` column by using index after the splitting.
# > hint: use `dir(data['vaccines'].str)` to see list of useful methods

# %%
splitted_vaccines = data['vaccines'].str.split(', ',expand=True)

# %%
data['first_vac'] = splitted_vaccines[0]

# %% [markdown]
# ### Membership Constraints
#
#
# > by using `dir(data)` we can find some useful methods :
# > - set()
# > - a.intersection(b)
# > - a.union(b)
# > - a.difference(b)
# > - a.symmetric_difference(b)
# > - a.isin(b)

# %% [markdown]
# <hr />
# <font color=red size=5 id="t10"> Task 10 :</font>
#
# use set operator for:
#
# - make a set of all vaccines name as `all_vaccines`
# > hint: iterate on columns add union each set of them
#
# - is there any vaccines in `all_vaccines` set that doesn't represent in `first_vac` ?

# %%
all_vaccines = set()

for i in splitted_vaccines: #loop column
    all_vaccines = all_vaccines.union(set(splitted_vaccines[i].dropna()))
    
print(all_vaccines)
# Out:
# {'Medigen', 'ZF2001', 'Sinopharm/Beijing', 'Abdala', 'Johnson&Johnson', 'Soberana02', 'CanSino', 'Moderna', 'Covaxin', 'EpiVacCorona', 'Sinopharm/HayatVax', 'Sinovac', 'Oxford/AstraZeneca', 'Pfizer/BioNTech', 'QazVac', 'COVIran Barekat', 'Sputnik V', 'Sinopharm/Wuhan'}

# %%
all_vaccines.difference(set(data['first_vac']))
# Out:
# {'Sinopharm/HayatVax', 'Sinopharm/Wuhan', 'Sinovac', 'Soberana02', 'ZF2001'}

# %% [markdown]
# <hr />
#
# ### Cleaning Text Data
#
# <font color=red size=5 id="t11"> Task 11 :</font>
#
# by using `set` operation and `str` method:
#
# - extract all unique domain names
# > - remove protocol <br>
# > - remove subdomain (just `www.`)
# > - remove page path
#
# ![image.png](https://blog.hubspot.com/hs-fs/hubfs/anatomy-of-web-address.jpg?width=600&name=anatomy-of-web-address.jpg)

# %%
web_sites = data.source_website.str.replace('https://','').str.replace('www.','').str.split('/',expand=True)[0]

set(web_sites)
# Out:
# <ipython-input-23-d01ac5ce714d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   web_sites = data.source_website.str.replace('https://','').str.replace('www.','').str.split('/',expand=True)[0]
# {'africacdc.org',
#  'ais.paho.org',
#  'app.powerbi.com',
#  'arcgis.com',
#  'asi.saglik.gov.ct.tr',
#  'ba.n1info.com',
#  'bakuna.cw',
#  'ccss.sa.cr',
#  'cdc.gov.tw',
#  'corona.fo',
#  'corona.moh.gov.jo',
#  'corona.nun.gl',
#  'coronavirus.bg',
#  'coronavirus.data.gov.uk',
#  'coronavirus2020.kz',
#  'covid-19.sledilnik.org',
#  'covid.cdc.gov',
#  'covid.is',
#  'covid19.gob.sv',
#  'covid19.gov.ag',
#  'covid19.gov.gg',
#  'covid19.gov.im',
#  'covid19.moh.gov.sa',
#  'covid19.mohp.gov.np',
#  'covid19.moph.gov.qa',
#  'covid19.ssi.dk',
#  'covid19.who.int',
#  'covid19asi.saglik.gov.tr',
#  'covid19ireland-geohive.hub.arcgis.com',
#  'covid19response.lc',
#  'covid19tracker.ca',
#  'covidlive.com.au',
#  'covidodgovor.me',
#  'covidvaccine.gov.hk',
#  'dashboard.cowin.gov.in',
#  'data.gouv.fr',
#  'data.gov.gr',
#  'data.gov.lv',
#  'data.public.lu',
#  'datadashboard.health.gov.il',
#  'datelazi.ro',
#  'datosabiertos.gob.pe',
#  'ddc.moph.go.th',
#  'docs.google.com',
#  'ecdc.europa.eu',
#  'en.trend.az',
#  'epid.gov.lk',
#  'epistat.wiv-isp.be',
#  'experience.arcgis.com',
#  'exploregov.ky',
#  'facebook.com',
#  'fcsc.gov.ae',
#  'fhi.no',
#  'fohm.se',
#  'github.com',
#  'gogov.ru',
#  'gouv.mc',
#  'gov.je',
#  'gov.mo',
#  'gov.pl',
#  'government.aw',
#  'gtmvigilanciacovid.shinyapps.io',
#  'guineasalud.org',
#  'health.govt.nz',
#  'healthalert.gov.bh',
#  'http:',
#  'ikon.mn',
#  'impact.cib.gov.lb',
#  'impfdashboard.de',
#  'info.gesundheitsministerium.gv.at',
#  'kantei.go.jp',
#  'koronavirus.gov.hu',
#  'koronavirus.hr',
#  'koronavirusinfo.az',
#  'laatjevaccineren.sr',
#  'moh.gov.cy',
#  'moh.gov.gm',
#  'moh.gov.sg',
#  'moh.gov.vn:443',
#  'monitor.uruguaysevacuna.gub.uy',
#  'mscbs.gob.es',
#  'ncoc.gov.pk',
#  'ncv.kdca.go.kr',
#  'news.abs-cbn.com',
#  'newsaf.cgtn.com',
#  'onemocneni-aktualne.mzcr.cz',
#  'opendata.digilugu.ee',
#  'opendata.swiss',
#  'qsprod.saude.gov.br',
#  'raw.githubusercontent.com',
#  'rivm.nl',
#  'rtc-planning.maps.arcgis.com',
#  'sacoronavirus.co.za',
#  'sainthelena.gov.sh',
#  'salud.msp.gob.cu',
#  'sampo.thl.fi',
#  'shendetesia.gov.al',
#  'stats.pacificdata.org',
#  'twitter.com',
#  'unidoscontraelcovid.gob.bo',
#  'vaccinare.gov.md',
#  'vaccination.covid19.gov.ua',
#  'vaccination.moh.gov.jm',
#  'vaccines.ncdc.ge',
#  'vaccinocovid.iss.sm',
#  'vacunas.panamasolidario.gob.pa',
#  'vacunate.gob.do',
#  'vakcinacija.gov.rs',
#  'vaksin.kemkes.go.id',
#  'vc.emed.gov.kg',
#  'who.int',
#  'who.maps.arcgis.com'}

# %% [markdown]
# ### Uniformity
#  when we face various format or scale in a column:
#
# <font color=green>e.g :</font>
#
# ``` date column has various formats  ```
#
# ``` total_vaccinations scale is different ```

# %%
covid_Uniformity = pd.read_csv('covid_Uniformity.csv')
covid_Uniformity
# Out:
#    Unnamed: 0   country iso_code                 date  total_vaccinations  \
# 0       18480   Iceland      ISL           30/12/2020            4875.000
# 1       19243      Iran      IRN           02/08/2021               1.756
# 2       24589     Macao      MAC           08/02/2021               1.029
# 3        1107  Anguilla      AIA  2021-02-04 00:00:00               1.825
# 4        8976     Congo      COG  2021-04-14 00:00:00           14297.000
#
#                                             vaccines  \
# 0  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 1  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 2                 Pfizer/BioNTech, Sinopharm/Beijing
# 3                                 Oxford/AstraZeneca
# 4  Moderna, Oxford/AstraZeneca, Sinopharm/Beijing...
#
#                                          source_name  \
# 0                              Directorate of Health
# 1                          World Health Organization
# 2                                Government of Macao
# 3                          World Health Organization
# 4  Africa Centres for Disease Control and Prevention
#
#                                       source_website
# 0  https://www.covid.is/tolulegar-upplysingar-bol...
# 1                           https://covid19.who.int/
# 2            https://www.gov.mo/zh-hant/news/814428/
# 3  https://ais.paho.org/imm/IM_DosisAdmin-Vacunac...
# 4        https://africacdc.org/covid-19-vaccination/

# %% [markdown]
# <hr />
# <font color=red size=5 id="t12"> Task 12 :</font>
#
# > - make a unique format for date <br>
# > - rescale rows with a value of per thousand of `total_vaccinations`

# %%
covid_Uniformity['date'] = pd.to_datetime(covid_Uniformity['date'])

TV_per_thousand = covid_Uniformity.loc[covid_Uniformity['total_vaccinations']<1000,'total_vaccinations']

covid_Uniformity.loc[covid_Uniformity['total_vaccinations']<1000,'total_vaccinations'] = TV_per_thousand *1000

covid_Uniformity
# Out:
#    Unnamed: 0   country iso_code       date  total_vaccinations  \
# 0       18480   Iceland      ISL 2020-12-30              4875.0
# 1       19243      Iran      IRN 2021-02-08              1756.0
# 2       24589     Macao      MAC 2021-08-02              1029.0
# 3        1107  Anguilla      AIA 2021-02-04              1825.0
# 4        8976     Congo      COG 2021-04-14             14297.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 1  COVIran Barekat, Covaxin, Oxford/AstraZeneca, ...
# 2                 Pfizer/BioNTech, Sinopharm/Beijing
# 3                                 Oxford/AstraZeneca
# 4  Moderna, Oxford/AstraZeneca, Sinopharm/Beijing...
#
#                                          source_name  \
# 0                              Directorate of Health
# 1                          World Health Organization
# 2                                Government of Macao
# 3                          World Health Organization
# 4  Africa Centres for Disease Control and Prevention
#
#                                       source_website
# 0  https://www.covid.is/tolulegar-upplysingar-bol...
# 1                           https://covid19.who.int/
# 2            https://www.gov.mo/zh-hant/news/814428/
# 3  https://ais.paho.org/imm/IM_DosisAdmin-Vacunac...
# 4        https://africacdc.org/covid-19-vaccination/

# %% [markdown]
# ### Completness
#
# > by using `dir(data)` we can find some useful methods :
# > - isna
# > - fillna
# > - dropna

# %%
# !conda install missingno
import missingno as mnso

# %%
mnso.matrix(data)
plt.show()

# %%
mnso.matrix(data.sort_values(by=['people_vaccinated']))
plt.show()

# %% [markdown]
# <hr />
# <font color=red size=5 id="t13"> Task 13 :</font>
#
# complete below code to fill missing values.
# > you can use `mean` or `median` or `mode`

# %%
mode_complete_data    = data.copy()

columns               = ['total_vaccinations','people_vaccinated','people_fully_vaccinated',
                         'daily_vaccinations_raw', 'daily_vaccinations','total_vaccinations_per_hundred', 
                         'people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred']

mode_complete_data[columns] = mode_complete_data[columns].fillna(mode_complete_data.median().iloc[0])

# %%
mnso.matrix(mode_complete_data)
plt.show();

# %% [markdown]
# <hr />
# <font color=red size=5 id="t14"> Task 14 :</font>
#
# Was what we did right (fill missing values)? why? explain.

# %% [markdown]
# <div dir="rtl" lang="fa" style="color:purple;font">این کار درست نیست زیرا تمام مقادیر نال ستونهای مختلف با مقدار میانه ستون total_vaccinations پرشده است که منطقی نیست و باید سیاست جایگزینی مناسب تری پیدا کرد.</div>

# %% [markdown]
# <hr />
#
# # Data statistics :
# > by using `dir(data)` we can find some useful methods :
# > - .describe()
# > - .dtypes()
# > - .info()
#
#
# > - .count()
# > - .corr()
# > - .corrwith()
# > - .cov()
# > - .idxmax()
# > - .idxmin()
# > - .max()
# > - .mean()
# > - .median()
# > - .min()
# > - .mode()
# > - .std()
# > - .quantile()
# > - .skew()

# %% [markdown]
# <font color=red size=5 id="t15"> Task 15 :</font>
#
# report statistics on `data` columns

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.508400e+04       2.394600e+04             2.104800e+04
# mean         2.048794e+07       8.757993e+06             5.583303e+06
# std          1.173603e+08       3.430173e+07             2.211721e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          2.077678e+05       1.668525e+05             8.035850e+04
# 50%          1.459863e+06       9.981035e+05             6.352150e+05
# 75%          7.737194e+06       4.679778e+06             3.270408e+06
# max          2.180986e+09       1.100842e+09             1.022207e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.060000e+04        4.567700e+04
# mean             2.597850e+05        1.308535e+05
# std              1.317281e+06        8.758538e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.898000e+03        8.710000e+02
# 50%              2.410650e+04        6.774000e+03
# 75%              1.116888e+05        4.169500e+04
# max              2.474100e+07        2.242429e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    25084.000000                   23946.000000
# mean                        43.740659                      26.569498
# std                         45.044427                      24.458658
# min                          0.000000                       0.000000
# 25%                          5.270000                       4.112500
# 50%                         26.440000                      18.600000
# 75%                         73.442500                      46.300000
# max                        235.390000                     118.270000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         21048.000000                    45677.000000
# mean                             19.689742                     3547.603520
# std                              21.467135                     4429.261509
# min                               0.000000                        0.000000
# 25%                               2.300000                      505.000000
# 50%                              10.645000                     2191.000000
# 75%                              32.252500                     5307.000000
# max                             117.120000                   117497.000000

# %% [markdown]
# <hr>

# %% [markdown]
# # Data manipulation :
# > by using `dir(data)` we can find some useful methods :
# > - .merge()
# > - .concat()

# %% [markdown]
# <hr />
# <font color=red size=5 id="t16"> Task 16 :</font>
#
# fill below code to merge Iran vs Iraq on date

# %%
ir = data[data['country']=='Iran'][['country','date','daily_vaccinations_per_million']].copy()
iq = data[data['country']=='Iraq'][['country','date','daily_vaccinations_per_million']].copy()

pd.merge(ir , iq, on='date' ,how='inner',suffixes=('_ir', '_iq'))
# Out:
#     country_ir        date  daily_vaccinations_per_million_ir country_iq  \
# 0         Iran  2021-03-01                               45.0       Iraq
# 1         Iran  2021-03-02                               45.0       Iraq
# 2         Iran  2021-03-03                               45.0       Iraq
# 3         Iran  2021-03-04                               45.0       Iraq
# 4         Iran  2021-03-05                               45.0       Iraq
# ..         ...         ...                                ...        ...
# 190       Iran  2021-09-07                             5763.0       Iraq
# 191       Iran  2021-09-08                             6591.0       Iraq
# 192       Iran  2021-09-09                             7419.0       Iraq
# 193       Iran  2021-09-10                             8247.0       Iraq
# 194       Iran  2021-09-11                             9075.0       Iraq
#
#      daily_vaccinations_per_million_iq
# 0                                  NaN
# 1                                 23.0
# 2                                 23.0
# 3                                 23.0
# 4                                 23.0
# ..                                 ...
# 190                             4546.0
# 191                             7755.0
# 192                             8660.0
# 193                             9565.0
# 194                            10469.0
#
# [195 rows x 5 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# # Data visualization :
# > by using `dir(data)` we can find some useful methods :
# > - .plot()
# > - .hist()
# > - .boxplot()

# %% [markdown]
# <hr />
# <font color=red size=5 id="t17"> Task 17 :</font>
#
# Fill below code by a numeric column

# %%
data.groupby('country').sum()['people_vaccinated'].plot();

# %%
data[data['country']=='Jersey'].loc[:,['date','people_vaccinated']].hist();

# %% [markdown]
# <hr>
# <font size=3 color=purple> you can also use matplotlib to for abow plots</font>

# %%
Lebanon = data[(data['country']=='Lebanon') & (data['date']> '2021-03-15') & (data['date'] < '2021-04-15')]
Lebanon = Lebanon.loc[:,['date','daily_vaccinations']]
plt.figure(figsize=[18,6])
plt.plot(Lebanon['date'].str[5:],Lebanon['daily_vaccinations'])
plt.title("Lebanon daily covid vaccinations from 3-16 to 4-14 of 2021")
plt.xlabel('date')
plt.ylabel('vaccine doses')
plt.xticks(rotation=45);

# %% [markdown]
# <hr>
# <hr>
# <font size=4 color=lightblue>$Keep$ $faith$  $in$  $yourself$  $and$  $trust$  $the$  $process$  $...$</font>
